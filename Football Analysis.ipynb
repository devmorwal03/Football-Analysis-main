# %%
from ultralytics import YOLO

# %%
model = YOLO('models/best.pt')

## save the results
result = model.predict('08fd33_4.mp4',save = True)
print(result[0])
print('================================')
for box in result[0].boxes:
    print(box)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) d:\Projects\Football Analysis sytem\08fd33_4.mp4: 384x640 1 ball, 1 goalkeeper, 18 players, 3 referees, 493.4ms
# video 1/1 (frame 2/750) d:\Projects\Football Analysis sytem\08fd33_4.mp4: 384x640 1 ball, 1 goalkeeper, 18 players, 3 referees, 425.5ms
# video 1/1 (frame 3/750) d:\Projects\Football Analysis sytem\08fd33_4.mp4: 384x640 1 goalkeeper, 19 players, 3 referees, 463.0ms
# ...
